# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

file_path="/home/user/Scrivania/PhD/DGM/code/IMTSF_DGM/data/mimic/raw/physionet.org/files/mimiciii/1.4/"

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 300)

# %%
adm=pd.read_csv(file_path+"Admissions_processed.csv")

# %% [markdown]
# We now consider the prescriptions dataset. We select only the patients present in the cleaned admission file

# %%
presc=pd.read_csv(file_path+"PRESCRIPTIONS.csv")

#Restrict the dataset to the previously selected admission ids only.
adm_ids=list(adm["HADM_ID"])
presc=presc.loc[presc["HADM_ID"].isin(adm_ids)]

print("Number of patients remaining in the database: ")
print(presc["SUBJECT_ID"].nunique())
# Out:
# /tmp/ipykernel_32528/2126377325.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   presc=pd.read_csv(file_path+"PRESCRIPTIONS.csv")
# Number of patients remaining in the database:
# 22595

# %%
#This part is for selecting the x most frequent prescriptions. Instead we use the list of prescriptions as in the paper.

n_best=10
#For each item, evaluate the number of patients who have been given this item.
pat_for_item=presc.groupby("DRUG")["SUBJECT_ID"].nunique()
#Order by occurence and take the 20 best (the ones with the most patients)
frequent_labels=pat_for_item.sort_values(ascending=False)[:n_best]

#Select only the time series with high occurence.
presc2=presc.loc[presc["DRUG"].isin(list(frequent_labels.index))].copy()

print("Number of patients remaining in the database: ")
print(presc2["SUBJECT_ID"].nunique())
# Out:
# Number of patients remaining in the database:
# 22593

# %%
#Select entries whose drug name is in the list from the paper.
drugs_list=["Aspirin","Bisacodyl","Docusate Sodium","D5W","Humulin-R Insulin","Potassium Chloride","Magnesium Sulfate","Metoprolol Tartrate","Sodium Chloride 0.9%  Flush","Pantoprazole"]
presc2=presc.loc[presc["DRUG"].isin(drugs_list)]

print("Number of patients remaining in the database: ")
print(presc2["SUBJECT_ID"].nunique())
# Out:
# Number of patients remaining in the database:
# 22565

# %% [markdown]
# ### Units Cleaning
#
# #### 1) In amounts

# %%
#Verification that all input labels have the same amounts units.

#Units correction
presc2=presc2.drop(presc2.loc[presc2["DOSE_UNIT_RX"].isnull()].index).copy()
presc2=presc2.drop(presc2.loc[(presc2["DRUG"]=="Acetaminophen")&(presc2["DOSE_UNIT_RX"]!="mg")].index).copy()
presc2.loc[(presc2["DRUG"]=="D5W")&(presc2["DOSE_UNIT_RX"]=="ml"),"DOSE_UNIT_RX"]="mL"
presc2=presc2.drop(presc2.loc[(presc2["DRUG"]=="D5W")&(presc2["DOSE_UNIT_RX"]!="mL")].index).copy()
presc2=presc2.drop(presc2.loc[(presc2["DRUG"]=="Heparin")&(presc2["DOSE_UNIT_RX"]!="UNIT")].index).copy()
presc2=presc2.drop(presc2.loc[(presc2["DRUG"]=="Insulin")&(presc2["DOSE_UNIT_RX"]!="UNIT")].index).copy()
presc2=presc2.drop(presc2.loc[(presc2["DRUG"]=="Magnesium Sulfate")&(presc2["DOSE_UNIT_RX"]!="gm")].index).copy()
presc2=presc2.drop(presc2.loc[(presc2["DRUG"]=="Potassium Chloride")&(presc2["DOSE_UNIT_RX"]!="mEq")].index).copy()
presc2.loc[(presc2["DRUG"]=="Sodium Chloride 0.9%  Flush")&(presc2["DOSE_UNIT_RX"]=="ml"),"DOSE_UNIT_RX"]="mL"
presc2=presc2.drop(presc2.loc[(presc2["DRUG"]=="Bisacodyl")&(presc2["DOSE_UNIT_RX"]!="mg")].index).copy()
presc2=presc2.drop(presc2.loc[(presc2["DRUG"]=="Humulin-R Insulin")&(presc2["DOSE_UNIT_RX"]!="UNIT")].index).copy()
presc2=presc2.drop(presc2.loc[(presc2["DRUG"]=="Pantoprazole")&(presc2["DOSE_UNIT_RX"]!="mg")].index).copy()


print(presc2.groupby("DRUG")["DOSE_UNIT_RX"].value_counts())
# Out:
# DRUG                         DOSE_UNIT_RX
# Aspirin                      mg              14978
# Bisacodyl                    mg              22573
# D5W                          mL              66611
# Docusate Sodium              mg              26318
# Humulin-R Insulin            UNIT             1841
# Magnesium Sulfate            gm              45885
# Metoprolol Tartrate          mg              34200
# Pantoprazole                 mg              15669
# Potassium Chloride           mEq             97798
# Sodium Chloride 0.9%  Flush  mL              43484
# Name: count, dtype: int64

# %% [markdown]
# ### Check for outliers
#
# #### 1) In amounts

# %%
type(presc2["DOSE_VAL_RX"])

#We need to transform the value columns in float type.
original_num_entries=len(presc2.index)
#First transform the ranges (xx-yy) as the mean of the ranges.
range_df=presc2.loc[presc2["DOSE_VAL_RX"].str.contains("-")].copy()
range_df["First_digit"]=range_df["DOSE_VAL_RX"].str.split("-").str[0].astype(float)
range_df["Second_digit"]=range_df["DOSE_VAL_RX"].str.split("-").str[1]
range_df.loc[range_df["Second_digit"]=="",'Second_digit']=range_df.loc[range_df["Second_digit"]=="",'First_digit']
range_df["Second_digit"]=range_df["Second_digit"].astype(float)
range_df.head()
range_df["mean"]=(range_df["First_digit"]+range_df["Second_digit"])/2
range_df["DOSE_VAL_RX"]=range_df["mean"]
range_df.drop(columns=["First_digit","Second_digit","mean"],inplace=True)


#Now remove the entries with the - from the original df and force conversion to float.
presc3=presc2.drop(presc2.loc[presc2["DOSE_VAL_RX"].str.contains("-")].index).copy()
presc3["DOSE_VAL_RX"]=pd.to_numeric(presc2["DOSE_VAL_RX"], errors="coerce")
presc3.dropna(subset=["DOSE_VAL_RX"],inplace=True)

# presc2=presc3.append(range_df)
presc2 = pd.concat([presc3, range_df], ignore_index=True)

print("Lost entries in the process : {}".format(original_num_entries-len(presc2.index)))
# Out:
# Lost entries in the process : 3

# %%
presc2.loc[presc2["SUBJECT_ID"]==275]
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTDATE  \
# 1445  1506242         275   129886    219649.0  2170-10-07 00:00:00
# 1446  1507031         275   129886    219649.0  2170-10-07 00:00:00
# 1447  1507033         275   129886    219649.0  2170-10-07 00:00:00
# 1448  1507030         275   129886    219649.0  2170-10-07 00:00:00
# 1449  1507771         275   129886    219649.0  2170-10-08 00:00:00
# 1450  1506245         275   129886    219649.0  2170-10-08 00:00:00
# 1451  1506247         275   129886    219649.0  2170-10-09 00:00:00
# 1452  1506249         275   129886    219649.0  2170-10-09 00:00:00
# 1453  1506248         275   129886    219649.0  2170-10-09 00:00:00
# 1454  1506250         275   129886    219649.0  2170-10-09 00:00:00
# 1455  1506251         275   129886    219649.0  2170-10-10 00:00:00
# 1456  1506252         275   129886    219649.0  2170-10-10 00:00:00
# 1457  1506253         275   129886    219649.0  2170-10-10 00:00:00
# 1525  1506256         275   129886    219649.0  2170-10-11 00:00:00
# 1526  1506257         275   129886    219649.0  2170-10-11 00:00:00
# 1527  1506262         275   129886    219649.0  2170-10-12 00:00:00
# 1528  1507775         275   129886    219649.0  2170-10-13 00:00:00
# 1529  1507774         275   129886    219649.0  2170-10-13 00:00:00
# 1530  1506267         275   129886    219649.0  2170-10-13 00:00:00
# 1531  1506269         275   129886    219649.0  2170-10-13 00:00:00
# 1532  1506265         275   129886    219649.0  2170-10-13 00:00:00
# 1533  1506266         275   129886    219649.0  2170-10-13 00:00:00
# 1534  1506276         275   129886    219649.0  2170-10-14 00:00:00
# 1445           gm             4             ml       IV
# 1446           mL           250             ml  IV DRIP
# 1447           mL           250             ml  IV DRIP
# 1448           mL            50             ml  IV DRIP
# 1449          mEq            20             ml       IV
# 1450          mEq             4            CAP       PO
# 1451          mEq             4            CAP       PO
# 1452          mEq             2            PKT       PO
# 1453           gm             4             ml       IV
# 1454          mEq             3            PKT       PO
# 1455          mEq             4            CAP       PO
# 1456          mEq             2            PKT       PO
# 1457           gm             4             ml       IV
# 1525          mEq             4            CAP       PO
# 1526           gm             4             ml       IV
# 1527          mEq             2            PKT       PO
# 1528          mEq            20             ml       IV
# 1529           gm             8             ml       IV
# 1530          mEq             4            CAP       PO
# 1531          mEq             4            CAP       PO
# 1532          mEq             4            CAP       PO
# 1533          mEq             2            PKT       PO
# 1534           mg             1            TAB       PO
# 1535           mL           0.6            SYR       IV
# 1550          mEq             4            CAP       PO
# 1551          mEq            20             ml       IV
# 1552           mL             1            BTL  IV DRIP
# 1768          mEq             2            BAG       IV
# 1769          mEq             2            BAG       IV
# 1943           mg             2            TAB       PO
# 1944           mg             1           SUPP       PR
# 1945           mL           250             ml  IV DRIP
# 1946           mL           250             ml  IV DRIP

# %%
presc2.groupby("DRUG")["DOSE_VAL_RX"].describe()
# Out:
#                                count        mean         std    min    25%  \
# DRUG
# Aspirin                      14978.0  193.673124  121.438202    0.0   81.0
# Bisacodyl                    22572.0   10.103890   14.649621    5.0   10.0
# D5W                          66609.0  272.359829  217.836532    0.0  250.0
# Docusate Sodium              26318.0  100.993617   10.463871  100.0  100.0
# Humulin-R Insulin             1841.0  100.451657   14.342874    1.0  100.0
# Magnesium Sulfate            45885.0    2.504418    0.842204    0.0    2.0
# Metoprolol Tartrate          34200.0   22.998220   22.735655    0.0    5.0
# Pantoprazole                 15669.0   41.466845    7.638300    0.0   40.0
# Potassium Chloride           97798.0   36.655156   15.723851    0.0   20.0
# Sodium Chloride 0.9%  Flush  43484.0    3.997919    2.543027    1.0    3.0
#
#                                50%    75%     max
# DRUG
# Aspirin                       81.0  325.0   975.0
# Bisacodyl                     10.0   10.0  2210.0
# D5W                          250.0  250.0  3250.0
# Docusate Sodium              100.0  100.0   400.0
# Humulin-R Insulin            100.0  100.0   500.0
# Magnesium Sulfate              2.0    3.0    20.0
# Metoprolol Tartrate           12.5   25.0   200.0
# Pantoprazole                  40.0   40.0   120.0
# Potassium Chloride            40.0   40.0   420.0
# Sodium Chloride 0.9%  Flush    3.0    3.0   150.0

# %%
#Remove all entries whose rate is more than 4 std away from the mean.
presc_desc=presc2.groupby("DRUG")["DOSE_VAL_RX"].describe()
name_list=list(presc_desc.loc[presc_desc["count"]!=0].index)
for label in name_list:
    presc2=presc2.drop(presc2.loc[(presc2["DRUG"]==label)&(presc2["DOSE_VAL_RX"]>(presc_desc.loc[label,"mean"]+4*presc_desc.loc[label,"std"]))].index).copy()

print("Number of patients remaining in the database: ")
print(presc2["SUBJECT_ID"].nunique())
print("Number of datapoints remaining in the database: ")
print(len(presc2.index))
# Out:
# Number of patients remaining in the database:
# 22565
# Number of datapoints remaining in the database:
# 368261

# %%
presc2.groupby("DRUG")["DOSE_VAL_RX"].describe()
# Out:
#                                count        mean         std    min    25%  \
# DRUG
# Aspirin                      14977.0  193.620955  121.274299    0.0   81.0
# Bisacodyl                    22571.0   10.006424    0.433253    5.0   10.0
# D5W                          66567.0  270.661377  207.030172    0.0  250.0
# Docusate Sodium              26068.0  100.000000    0.000000  100.0  100.0
# Humulin-R Insulin             1830.0   99.580055    6.123123    1.0  100.0
# Magnesium Sulfate            45869.0    2.502457    0.831444    0.0    2.0
# Metoprolol Tartrate          34036.0   22.403900   21.051369    0.0    5.0
# Pantoprazole                 15086.0   39.975076    0.823609    0.0   40.0
# Potassium Chloride           97775.0   36.629209   15.556873    0.0   20.0
# Sodium Chloride 0.9%  Flush  43482.0    3.994193    2.443590    1.0    3.0
#
#                                50%    75%     max
# DRUG
# Aspirin                       81.0  325.0   650.0
# Bisacodyl                     10.0   10.0    40.0
# D5W                          250.0  250.0  1000.0
# Docusate Sodium              100.0  100.0   100.0
# Humulin-R Insulin            100.0  100.0   100.0
# Magnesium Sulfate              2.0    3.0     5.0
# Metoprolol Tartrate           12.5   25.0   100.0
# Pantoprazole                  40.0   40.0    40.0
# Potassium Chloride            40.0   40.0    90.0
# Sodium Chloride 0.9%  Flush    3.0    3.0    10.0

# %%
presc2['CHARTTIME']=pd.to_datetime(presc2["STARTDATE"], format='%Y-%m-%d %H:%M:%S')

#To avoid confounding labels with labels from other tables, we add "drug" to the name
presc2["DRUG"]=presc2["DRUG"]+" Drug"

# %%
presc2.to_csv(file_path+"PRESCRIPTIONS_processed.csv")

# %%
presc2['STARTDATE']=pd.to_datetime(presc2["STARTDATE"], format='%Y-%m-%d %H:%M:%S')
presc2['ENDDATE']=pd.to_datetime(presc2["ENDDATE"], format='%Y-%m-%d %H:%M:%S')

presc2["ELAPSED_TIME"]=(presc2["ENDDATE"]-presc2["STARTDATE"])
presc2["ELAPSED_DAYS"]=presc2["ELAPSED_TIME"].dt.days
plt.hist(presc2.loc[(presc2["ELAPSED_DAYS"].notnull()),"ELAPSED_DAYS"])
plt.show()

presc2.loc[(presc2["ELAPSED_DAYS"].notnull()),"ELAPSED_DAYS"].value_counts()
# Out:
# ELAPSED_DAYS
#  1.0     141013
#  0.0      66764
#  2.0      40628
#  3.0      32395
#  4.0      22359
#  5.0      15604
#  6.0      11302
#  7.0       8013
#  8.0       5967
#  9.0       4433
#  10.0      3645
#  11.0      2775
#  12.0      2255
#  13.0      1995
#  14.0      1514
#  15.0      1253
#  16.0       975
#  17.0       893
#  18.0       702
# -1.0        575
#  19.0       553
#  20.0       504
#  21.0       416
#  22.0       357
#  23.0       288
#  25.0       253
#  24.0       237
#  27.0       127
#  26.0       127
#  28.0        98
#  29.0        46
#  30.0        16
# -2.0          7
# -5.0          1
# -30.0         1
# -4.0          1
# Name: count, dtype: int64

# %%
presc2.loc[presc2["ELAPSED_DAYS"].isnull()]
# Out:
#          ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID  STARTDATE ENDDATE DRUG_TYPE  \
# 2532    1235207         458   183288    279940.0 2152-01-24     NaT      MAIN
# 2533    1235213         458   183288    279940.0 2152-01-24     NaT      MAIN
# 5416    1926835         979   163886         NaN 2163-02-25     NaT      BASE
# 6401     843038        1079   167362    291034.0 2156-12-22     NaT      BASE
# 6402     843040        1079   167362    291034.0 2156-12-22     NaT      BASE
# ...         ...         ...      ...         ...        ...     ...       ...
# 347586  1529407       95230   192633    210969.0 2183-11-21     NaT      MAIN
# 348925  1529417       95230   192633    210969.0 2183-11-22     NaT      MAIN
# 348926  1540002       95230   192633         NaN 2183-11-23     NaT      MAIN
# 355527  4041630       97762   107220         NaN        NaT     NaT      MAIN
# 359475  3660334       97543   136264         NaN        NaT     NaT      MAIN
#
#                                     DRUG                DRUG_NAME_POE  \
# 2532                   Pantoprazole Drug                 Pantoprazole
# 2533                   Pantoprazole Drug                 Pantoprazole
# 5416                            D5W Drug                          NaN
# 6401                            D5W Drug                          NaN
# 6402                            D5W Drug                          NaN
# ...                                  ...                          ...
# 347586  Sodium Chloride 0.9%  Flush Drug  Sodium Chloride 0.9%  Flush
# 348925                 Pantoprazole Drug                 Pantoprazole
# 348926          Metoprolol Tartrate Drug          Metoprolol Tartrate
# 355527                 Pantoprazole Drug                 Pantoprazole
# 359475                 Pantoprazole Drug                 Pantoprazole
#
#                   DRUG_NAME_GENERIC FORMULARY_DRUG_CD     GSN           NDC  \
# 2532                   Pantoprazole            PANT40  027462  8.084199e+06
# 2533                   Pantoprazole            PANT40  027462  8.084199e+06
# 5416                            NaN          CLINBASE     NaN  0.000000e+00
# 6401                            NaN            D5W250  001972  3.380017e+08
# 6402                            NaN            D5W250  001972  3.380017e+08
# ...                             ...               ...     ...           ...
# 347586  Sodium Chloride 0.9%  Flush         NACLFLUSH     NaN  0.000000e+00
# 348925                 Pantoprazole            PANT40  027462  8.084199e+06
# 348926          Metoprolol Tartrate            METO25  050631  5.107903e+10
# 355527      Pantoprazole (Self Med)          PANT40SM  027462  6.838703e+10
# 359475      Pantoprazole (Self Med)          PANT40SM  027462  6.838703e+10
#
#        PROD_STRENGTH  DOSE_VAL_RX DOSE_UNIT_RX FORM_VAL_DISP FORM_UNIT_DISP  \
# 2532        40MG TAB         40.0           mg             1            TAB
# 2533        40MG TAB         40.0           mg             1            TAB
# 5416        50ML BAG         50.0           mL             1            BAG
# 6401       250ML BAG        250.0           mL           250             ml
# 6402       250ML BAG        250.0           mL           250             ml
# ...              ...          ...          ...           ...            ...
# 347586       Syringe          3.0           mL           0.6            SYR
# 348925   40mg Tablet         40.0           mg             1            TAB
# 348926   25mg Tablet         12.5           mg           0.5            TAB
# 355527  40 mg Tablet         40.0           mg             1            TAB
# 359475  40 mg Tablet         40.0           mg             1            TAB
#
#           ROUTE  CHARTTIME ELAPSED_TIME  ELAPSED_DAYS
# 2532         PO 2152-01-24          NaT           NaN
# 2533         PO 2152-01-24          NaT           NaN
# 5416         IV 2163-02-25          NaT           NaN
# 6401    IV DRIP 2156-12-22          NaT           NaN
# 6402    IV DRIP 2156-12-22          NaT           NaN
# ...         ...        ...          ...           ...
# 347586       IV 2183-11-21          NaT           NaN
# 348925       PO 2183-11-22          NaT           NaN
# 348926    PO/NG 2183-11-23          NaT           NaN
# 355527       PO        NaT          NaT           NaN
# 359475       PO        NaT          NaT           NaN
#
# [169 rows x 22 columns]
